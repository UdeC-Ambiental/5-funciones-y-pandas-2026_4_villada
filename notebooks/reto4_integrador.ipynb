# %% [markdown]
# # Reto 4 – Integrador de resultados
#
# **Objetivo:** Combinar los análisis de los compañeros y crear un resumen general del ecosistema.
#
# Carga el conjunto de datos y explora las variables relevantes.

# %%
import pandas as pd

df = pd.read_csv("../data/resultados_experimentos.csv")
df.head()

# %% [markdown]
# ## Exploración inicial
# Describe las columnas y analiza los tipos de datos.

# %%
# Escribe tu código aquí para explorar el DataFrame

# %% [markdown]
# ## Desarrollo del reto
# Aplica funciones y análisis según el objetivo. Usa `def` para definir tus funciones.

# %%
# Crea aquí tus funciones y análisis

# %% [markdown]
# ## Interpretación de resultados
# Escribe tus observaciones y conclusiones sobre los patrones encontrados.

# %% [markdown]
# ## Conclusiones
# Se vio la importancia de este desarrollo al permitir aplicar herramientas de programacion, con el fin de pode analisar informacion ambientales mediante el uso de la biblioteca de pandas. a traves de la integracion de los datos obtenidos por cada miembro del grupo, fue posible hacer una organizacion, un proceso y un respetivo analizis en la informacion experimental de una manera eficiente. Por otra parte, los cálculos de promedios, su respectivo análisis de correlación y la elaboración de ciertos gráficos, nos permitieron una facilitacion a la interpretación de los resultados y su identificación de relaciones entre las variables de ambiente y de biomasa.

# %% [markdown]
# ## Observaciones
# 1. La respectiva integración de los datos de todos los integrantes, nos permitió obtener una visión más amplia, ademas de completa de los resultados experimentales los cuales se obtuvieron durante el análisis ambiental.
# 2. Se evidenció que la biomasa presenta variaciones entre los diferentes sitios analisados, lo que nos indica que las condiciones ambientales influyen directamente en su comportamiento.
# 3. El uso de funciones en Python nos ayudó a automatizar los procesos de cálculo y una organización de datos, con esto siendo mucho más eficiente al desarrollo del trabajo.
# 4. La biblioteca pandas nos facilitó el respectivo manejo de grandes cantidades de información y nos permitió realizar un análisis estadísticos de manera mucho mas rápida y ordenada.
# 5. El análisis de correlación permitió identificar la variable con una mayor relación respecto a la biomasa, facilitando asi la interpretación de los resultados experimentales.
# 6. El gráfico de dispersión permitió visualizar de forma clara una relación entre la biomasa y la variable con más correlacion, con esto ayudando a comprender de una forma mejor el comportamiento de los datos.
